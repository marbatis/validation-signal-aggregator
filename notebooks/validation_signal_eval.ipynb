# %% [markdown]
# # Validation Signal Evaluation

# %%
import json
from pathlib import Path
for p in Path('../data/builds').glob('*.json'):
    payload = json.loads(p.read_text())
    print(payload['build_id'], payload['validation_suites']['failed'])
